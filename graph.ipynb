# %%
import pandas as pd
import numpy as np
from mlxtend.frequent_patterns import apriori, association_rules
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import networkx as nx

df = pd.read_csv("data1.csv")
df
# Out:
#     node1   node2
# 0   ACAD8   ACAA2
# 1   ACAD8   ACADS
# 2   ACAD8  ACADSB
# 3   ACAD8  BCKDHA
# 4   ACAD8  BCKDHB
# 5   ACAD8     DBT
# 6   ACAD8     DLD
# 7   ACAD8   ECHS1
# 8   ACAD8  EHHADH
# 9   ACAD8   HADHA
# 10  COPG2   ARCN1
# 11  COPG2    COPA
# 12  COPG2   COPB1
# 13  COPG2   COPB2
# 14  COPG2    COPE
# 15  COPG2   COPG1
# 16  COPG2   COPZ1
# 17  COPG2   COPZ2
# 18  COPG2    GBF1

# %%
records = []
for i in range(0,18):
    records.append([str(df.values[i, j]) for j in range(0,2)])
records
# Out:
# [['ACAD8', 'ACAA2'],
#  ['ACAD8', 'ACADS'],
#  ['ACAD8', 'ACADSB'],
#  ['ACAD8', 'BCKDHA'],
#  ['ACAD8', 'BCKDHB'],
#  ['ACAD8', 'DBT'],
#  ['ACAD8', 'DLD'],
#  ['ACAD8', 'ECHS1'],
#  ['ACAD8', 'EHHADH'],
#  ['ACAD8', 'HADHA'],
#  ['COPG2', 'ARCN1'],
#  ['COPG2', 'COPA'],
#  ['COPG2', 'COPB1'],
#  ['COPG2', 'COPB2'],
#  ['COPG2', 'COPE'],
#  ['COPG2', 'COPG1'],
#  ['COPG2', 'COPZ1'],
#  ['COPG2', 'COPZ2']]

# %%
df["node1"].unique()
# Out:
# array(['ACAD8', 'COPG2'], dtype=object)

# %%
# The original dataset is from:
# Gabasova, E. (2016). Star Wars social network. DOI: https://doi.org/10.5281/zenodo.1411479
# 
# Simplified by Federico Albanese.

characters =['ACAD8', 'COPG2']

edges = [['ACAD8', 'ACAA2'],
 ['ACAD8', 'ACADS'],
 ['ACAD8', 'ACADSB'],
 ['ACAD8', 'BCKDHA'],
 ['ACAD8', 'BCKDHB'],
 ['ACAD8', 'DBT'],
 ['ACAD8', 'DLD'],
 ['ACAD8', 'ECHS1'],
 ['ACAD8', 'EHHADH'],
 ['ACAD8', 'HADHA'],
 ['COPG2', 'ARCN1'],
 ['COPG2', 'COPA'],
 ['COPG2', 'COPB1'],
 ['COPG2', 'COPB2'],
 ['COPG2', 'COPE'],
 ['COPG2', 'COPG1'],
 ['COPG2', 'COPZ1'],
 ['COPG2', 'COPZ2']]

starWars = nx.Graph()


starWars.add_nodes_from(characters)
starWars.add_edges_from(edges)
pos = nx.circular_layout(starWars)
nx.draw(starWars, pos=pos, with_labels = True)

# %%
import pandas as pd
import numpy as np
from mlxtend.frequent_patterns import apriori, association_rules
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import networkx as nx

df = pd.read_csv("data2.csv")
df
# Out:
#     node1  node2
# 0    MYH1   MYL1
# 1    MYH1  MYLPF
# 2    MYH1  MYL6B
# 3    MYH1   MYH2
# 4    MYH1   MYL9
# 5    MYH1   MYL3
# 6    MYH1   MYL5
# 7    MYH1   MYH8
# 8    MYH1  MYH10
# 9    MYH1   MYH7
# 10  ACTN2    TTN
# 11  ACTN2   LDB3
# 12  ACTN2    VCL
# 13  ACTN2  ACTN4
# 14  ACTN2  MYOZ1
# 15  ACTN2  ACTN1
# 16  ACTN2   MYH6
# 17  ACTN2   MYH3
# 18  ACTN2   ACTB

# %%
records = []
for i in range(0,18):
    records.append([str(df.values[i, j]) for j in range(0,2)])
records
# Out:
# [['MYH1', 'MYL1'],
#  ['MYH1', 'MYLPF'],
#  ['MYH1', 'MYL6B'],
#  ['MYH1', 'MYH2'],
#  ['MYH1', 'MYL9'],
#  ['MYH1', 'MYL3'],
#  ['MYH1', 'MYL5'],
#  ['MYH1', 'MYH8'],
#  ['MYH1', 'MYH10'],
#  ['MYH1', 'MYH7'],
#  ['ACTN2', 'TTN'],
#  ['ACTN2', 'LDB3'],
#  ['ACTN2', 'VCL'],
#  ['ACTN2', 'ACTN4'],
#  ['ACTN2', 'MYOZ1'],
#  ['ACTN2', 'ACTN1'],
#  ['ACTN2', 'MYH6'],
#  ['ACTN2', 'MYH3']]

# %%
df["node1"].unique()
# Out:
# array(['MYH1', 'ACTN2'], dtype=object)

# %%
# Simplified by Federico Albanese.

characters =['MYH1', 'ACTN2']

edges = [['MYH1', 'MYL1'],
 ['MYH1', 'MYLPF'],
 ['MYH1', 'MYL6B'],
 ['MYH1', 'MYH2'],
 ['MYH1', 'MYL9'],
 ['MYH1', 'MYL3'],
 ['MYH1', 'MYL5'],
 ['MYH1', 'MYH8'],
 ['MYH1', 'MYH10'],
 ['MYH1', 'MYH7'],
 ['ACTN2', 'TTN'],
 ['ACTN2', 'LDB3'],
 ['ACTN2', 'VCL'],
 ['ACTN2', 'ACTN4'],
 ['ACTN2', 'MYOZ1'],
 ['ACTN2', 'ACTN1'],
 ['ACTN2', 'MYH6'],
 ['ACTN2', 'MYH3']]

starWars = nx.Graph()


starWars.add_nodes_from(characters)
starWars.add_edges_from(edges)
pos = nx.circular_layout(starWars)
nx.draw(starWars, pos=pos, with_labels = True)

# %%
import pandas as pd
import numpy as np
from mlxtend.frequent_patterns import apriori, association_rules
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import networkx as nx

df = pd.read_csv("data3.csv")
df
# Out:
#       node1     node2
# 0    TIMM22    TIMM10
# 1    TIMM22   TIMM10B
# 2    TIMM22    TIMM23
# 3    TIMM22     TIMM9
# 4    TIMM22    TOMM22
# 5    TIMM22    TOMM40
# 6    TIMM22     TOMM7
# 7    TIMM22   TOMM70A
# 8    TIMM22       AGK
# 9    TIMM22  C19orf52
# 10  RAPGEF3     ABCC8
# 11  RAPGEF3     AKAP6
# 12  RAPGEF3    KCNJ11
# 13  RAPGEF3    LRPAP1
# 14  RAPGEF3     MAPK7
# 15  RAPGEF3     PDE3B
# 16  RAPGEF3    RANBP2
# 17  RAPGEF3     RAP1A
# 18  RAPGEF3     RAP1B

# %%
records = []
for i in range(0,18):
    records.append([str(df.values[i, j]) for j in range(0,2)])
records
# Out:
# [['TIMM22', 'TIMM10'],
#  ['TIMM22', 'TIMM10B'],
#  ['TIMM22', 'TIMM23'],
#  ['TIMM22', 'TIMM9'],
#  ['TIMM22', 'TOMM22'],
#  ['TIMM22', 'TOMM40'],
#  ['TIMM22', 'TOMM7'],
#  ['TIMM22', 'TOMM70A'],
#  ['TIMM22', 'AGK'],
#  ['TIMM22', 'C19orf52'],
#  ['RAPGEF3', 'ABCC8'],
#  ['RAPGEF3', 'AKAP6'],
#  ['RAPGEF3', 'KCNJ11'],
#  ['RAPGEF3', 'LRPAP1'],
#  ['RAPGEF3', 'MAPK7'],
#  ['RAPGEF3', 'PDE3B'],
#  ['RAPGEF3', 'RANBP2'],
#  ['RAPGEF3', 'RAP1A']]

# %%
df["node1"].unique()
# Out:
# array(['TIMM22', 'RAPGEF3'], dtype=object)

# %%
characters =['TIMM22', 'RAPGEF3', 'DUSP13']

edges = [['TIMM22', 'TIMM10'],
 ['TIMM22', 'TIMM10B'],
 ['TIMM22', 'TIMM23'],
 ['TIMM22', 'TIMM9'],
 ['TIMM22', 'TOMM22'],
 ['TIMM22', 'TOMM40'],
 ['TIMM22', 'TOMM7'],
 ['TIMM22', 'TOMM70A'],
 ['TIMM22', 'AGK'],
 ['TIMM22', 'C19orf52'],
 ['RAPGEF3', 'ABCC8'],
 ['RAPGEF3', 'AKAP6'],
 ['RAPGEF3', 'KCNJ11'],
 ['RAPGEF3', 'LRPAP1'],
 ['RAPGEF3', 'MAPK7'],
 ['RAPGEF3', 'PDE3B'],
 ['RAPGEF3', 'RANBP2'],
 ['RAPGEF3', 'RAP1A'],
 ['RAPGEF3', 'RAP1B'],
 ['RAPGEF3', 'RAP2B'],
 ['DUSP13', 'AADAC'],
 ['DUSP13', 'ADK'],
 ['DUSP13', 'AP3M1'],
 ['DUSP13', 'DHDH'],
 ['DUSP13', 'KAT6B'],
 ['DUSP13', 'KRT36'],
 ['DUSP13', 'LMNA'],
 ['DUSP13', 'PTPRR']]

starWars = nx.Graph()


starWars.add_nodes_from(characters)
starWars.add_edges_from(edges)
pos = nx.circular_layout(starWars)
nx.draw(starWars, pos=pos, with_labels = True)

# %%
import pandas as pd
import numpy as np
from mlxtend.frequent_patterns import apriori, association_rules
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import networkx as nx

df = pd.read_csv("data4.csv")
df
# Out:
#     node1    node2
# 0   CTLA4    B7RP1
# 1   CTLA4    CD274
# 2   CTLA4    CD276
# 3   CTLA4     CD80
# 4   CTLA4     CD86
# 5   CTLA4    FOXP3
# 6   CTLA4     GRB2
# 7   CTLA4      LCK
# 8   CTLA4     PTPN
# 9   PCGF6     CBX3
# 10  PCGF6     CBX4
# 11  PCGF6     CBX6
# 12  PCGF6     CBX7
# 13  PCGF6     E2F6
# 14  PCGF6  L3MBTL2
# 15  PCGF6    RING1
# 16  PCGF6     RNF2
# 17  PCGF6     RYBP
# 18  PCGF6     YAF2
# 19  ERO1L   ERO1LB
# 20  ERO1L    ERP44
# 21  ERO1L     GPX7
# 22  ERO1L     GPX8
# 23  ERO1L    HSPA5
# 24  ERO1L      INS
# 25  ERO1L     P4HB
# 26  ERO1L    PDIA3
# 27  ERO1L    PDIA4
# 28  ERO1L    TXNDC

# %%
records = []
for i in range(0,28):
    records.append([str(df.values[i, j]) for j in range(0,2)])
records
# Out:
# [['CTLA4', 'B7RP1'],
#  ['CTLA4', 'CD274'],
#  ['CTLA4', 'CD276'],
#  ['CTLA4', 'CD80'],
#  ['CTLA4', 'CD86'],
#  ['CTLA4', 'FOXP3'],
#  ['CTLA4', 'GRB2'],
#  ['CTLA4', 'LCK'],
#  ['CTLA4', 'PTPN'],
#  ['PCGF6', 'CBX3'],
#  ['PCGF6', 'CBX4'],
#  ['PCGF6', 'CBX6'],
#  ['PCGF6', 'CBX7'],
#  ['PCGF6', 'E2F6'],
#  ['PCGF6', 'L3MBTL2'],
#  ['PCGF6', 'RING1'],
#  ['PCGF6', 'RNF2'],
#  ['PCGF6', 'RYBP'],
#  ['PCGF6', 'YAF2'],
#  ['ERO1L', 'ERO1LB'],
#  ['ERO1L', 'ERP44'],
#  ['ERO1L', 'GPX7'],
#  ['ERO1L', 'GPX8'],
#  ['ERO1L', 'HSPA5'],
#  ['ERO1L', 'INS'],
#  ['ERO1L', 'P4HB'],
#  ['ERO1L', 'PDIA3'],
#  ['ERO1L', 'PDIA4']]

# %%
df["node1"].unique()
# Out:
# array(['CTLA4', 'PCGF6', 'ERO1L'], dtype=object)

# %%
characters =['CTLA4', 'PCGF6', 'ERO1L']

edges = [['CTLA4', 'B7RP1'],
 ['CTLA4', 'CD274'],
 ['CTLA4', 'CD276'],
 ['CTLA4', 'CD80'],
 ['CTLA4', 'CD86'],
 ['CTLA4', 'FOXP3'],
 ['CTLA4', 'GRB2'],
 ['CTLA4', 'LCK'],
 ['CTLA4', 'PTPN'],
 ['PCGF6', 'CBX3'],
 ['PCGF6', 'CBX4'],
 ['PCGF6', 'CBX6'],
 ['PCGF6', 'CBX7'],
 ['PCGF6', 'E2F6'],
 ['PCGF6', 'L3MBTL2'],
 ['PCGF6', 'RING1'],
 ['PCGF6', 'RNF2'],
 ['PCGF6', 'RYBP'],
 ['PCGF6', 'YAF2'],
 ['ERO1L', 'ERO1LB'],
 ['ERO1L', 'ERP44'],
 ['ERO1L', 'GPX7'],
 ['ERO1L', 'GPX8'],
 ['ERO1L', 'HSPA5'],
 ['ERO1L', 'INS'],
 ['ERO1L', 'P4HB'],
 ['ERO1L', 'PDIA3'],
 ['ERO1L', 'PDIA4']]

starWars = nx.Graph()


starWars.add_nodes_from(characters)
starWars.add_edges_from(edges)
pos = nx.circular_layout(starWars)
nx.draw(starWars, pos=pos, with_labels = True)
